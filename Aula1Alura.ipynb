# %% [markdown]
# <a href="https://colab.research.google.com/github/andresinpa/InmersionDatos_Alura/blob/main/Aula1Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRIMER ENCUENTRO DE INMERSION DE DATOS (ALURA)**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/otros/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños': 'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 2715  Apartamento  Apartamento en venta en Chico Norte             2      2
# 5099  Apartamento  Apartamento en venta en Bella Suiza             2      2
# 5435         Casa                Casa en venta en Bosa             3      1
# 5586  Apartamento      Apartamento en venta en Usaquén             3      2
# 8316         Casa       Casa en venta en Villa Alsacia             3      2
# 5132         Casa            Casa en venta en Engativa             4      1
# 5396  Apartamento  Apartamento en venta en Bella Suiza             3      3
# 3386  Apartamento         Apartamento en venta en Bosa             3      1
# 8915  Apartamento      Apartamento en venta en Usaquén             4      4
# 3600  Apartamento     Apartamento en venta en Cedritos             3      3
#
#       Area         Barrio                                    UPZ  \
# 2715   112    Chico Norte     CHAPINERO: Chicó Lago + El Refugio
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[100]
# Out:
# Tipo                                           Apartamento
# Descripcion     Apartamento en venta en Zona Noroccidental
# Habitaciones                                             2
# Banos                                                    1
# Area                                                    44
# Barrio                                  Zona Noroccidental
# UPZ                     CHAPINERO: Pardo Rubio + Chapinero
# Valor                                        $ 176.000.000
# Name: 100, dtype: object

# %%
inmuebles.iloc[100:120]
# Out:
#                     Tipo                                     Descripcion  \
# 100          Apartamento      Apartamento en venta en Zona Noroccidental
# 101          Apartamento          Apartamento en venta en Ciudad Salitre
# 102          Apartamento          Apartamento en venta en Quinta Paredes
# 103          Apartamento                Apartamento en venta en Hayuelos
# 104          Apartamento                 Apartamento en venta en Usaquén
# 105                 Casa                        Casa en venta en Usaquén
# 106          Apartamento                Apartamento en venta en Cedritos
# 107  Oficina/Consultorio  Oficina/Consultorio en venta en Ciudad Salitre
# 108          Apartamento           Apartamento en venta en Santa Barbara
# 109          Apartamento      Apartamento en venta en Zona Noroccidental
# 110          Apartamento                Apartamento en venta en Cedritos
# 111          Apartamento                 Apartamento en venta en Usaquén
# ...

# %%
inmuebles['Valor'][100]
# Out:
# '$ 176.000.000'

# %%
inmuebles['Valor'][100:120]
# Out:
# 100      $ 176.000.000
# 101      $ 680.000.000
# 102      $ 680.000.000
# 103      $ 217.000.000
# 104    $ 1.050.000.000
# 105      $ 375.000.000
# 106      $ 458.000.000
# 107    $ 2.000.000.000
# 108      $ 425.000.000
# 109      $ 318.000.000
# 110      $ 660.000.000
# 111      $ 730.000.000
# 112      $ 140.000.000
# 113      $ 343.000.000
# 114      $ 385.000.000
# 115    $ 1.300.000.000
# 116    $ 1.195.000.000
# 117      $ 519.000.000
# 118      $ 350.000.000
# 119      $ 202.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][100:110])
# Out:
# pandas.core.series.Series

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')

chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **AULA 2**

# %%
inmuebles.sample(12)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 4732  Apartamento  Apartamento en venta en Villa Alsacia             3      2
# 6624  Apartamento       Apartamento en venta en Engativa             3      2
# 1017  Apartamento        Apartamento en venta en Tintala             2      1
# 9270         Casa              Casa en venta en Engativa             3      3
# 6582  Apartamento       Apartamento en venta en Cedritos             2      1
# 5414  Apartamento           Apartamento en venta en Bosa             3      1
# 5403  Apartamento     Apartamento en venta en El Refugio             1      2
# 1880         Casa    Casa en venta en Rafael Uribe Uribe             6      4
# 4752  Apartamento           Apartamento en venta en Suba             3      2
# 1044  Apartamento        Apartamento en venta en Usaquén             3      2
# 6968         Casa            Casa en venta en La Calleja             4      5
# ...

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0] + inmuebles.Valor[9]
# Out:
# '$ 360.000.000$ 642.000.000'

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
from shutil import register_archive_format
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon',kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de los inmuebles en Bogota')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/otros/valor_inmuebles.png', format='png')
plt.show()
